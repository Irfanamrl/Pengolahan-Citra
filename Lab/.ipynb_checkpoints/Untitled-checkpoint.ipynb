# %%
from skimage import color, io
from skimage.transform import rescale
import matplotlib.pyplot as plt
from skimage.color import rgb2hsv

# %%
 i1 = io.imread('fasilkom.png')

# %%
plt.imshow(i1, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
dimension = i1.shape

# %%
io.imsave('fasilkombaru.png', i1)

# %%
plt.plot(x, x)
plt.plot(x, np.sin(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a80be4123adb> in <module>
# ----> 1 plt.plot(x, x)
#       2 plt.plot(x, np.sin(x))
#
# NameError: name 'x' is not defined

# %%
i2 = io.imread('flower.jpg')

# %%
plt.show()

# %%
i2.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-1572a82b030b> in <module>
# ----> 1 i2.show()
#
# AttributeError: 'Array' object has no attribute 'show'

# %%
plt.imshow(i2, cmap='hsv', vmin=0, vmax=255)
plt.show()

# %%
hsv_image = rgb2hsv(i2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-9c546aaa5434> in <module>
# ----> 1 hsv_image = rgb2hsv(i2)
#
# NameError: name 'rgb2hsv' is not defined
